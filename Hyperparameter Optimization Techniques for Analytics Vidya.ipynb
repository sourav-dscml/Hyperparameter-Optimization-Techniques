# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#importing packages
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

#Loading iris dataset from sklearn
iris = load_iris()

#Creating independent features
X = iris.data
#Creating traget features
y = iris.target

# %%
#Importing XGBoost
from xgboost import XGBClassifier

#Defining XGB classification model
clf = XGBClassifier()

# %%
#Importing packages from sklearn
from sklearn import preprocessing
from sklearn import model_selection
from sklearn import metrics

#defining a set of values as a dictionary for hyperparameters
param_grid = {
    "n_estimators":[100,200,300,400],
    "max_depth":[1,3,5,7],
    "reg_lambda":[.01,.1,.5]    
}

#declaring GridSearchCV model
model = model_selection.GridSearchCV(
    estimator = clf,
    param_grid = param_grid,
    scoring = 'accuracy',
    verbose = 10,
    n_jobs = 1,
    cv = 5    
)
#fitting values to the gridsearchcv model
model.fit(X,y)

#printing the best possible values to enhance accuracy
print(model.best_params_)
print()
print(model.best_estimator_)
#printing the best score
print(model.best_score_)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.01, score=0.900, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.1, score=0.900, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.1, score=0.933, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.1s remaining:    0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.1, score=1.000, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=1, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=100, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.01, score=0.900, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.1, score=0.900, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.1, score=1.000, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.5, score=0.900, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=1, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=200, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.01, score=0.900, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.1, score=0.900, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.1, score=1.000, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.5, score=0.900, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=1, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=300, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.01, score=0.967, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.01, score=0.967, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.01, score=0.900, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.01, score=0.933, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.01, score=1.000, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.1, score=0.900, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.1, score=0.933, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.1, score=1.000, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.5, score=0.967, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.5, score=0.967, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.5, score=0.900, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.5, score=0.933, total=   0.1s
# [CV] max_depth=1, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=1, n_estimators=400, reg_lambda=0.5, score=1.000, total=   0.1s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.1, score=1.000, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=100, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.01, score=0.967, total=   0.1s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.1, score=1.000, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=200, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.1, score=1.000, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=3, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=300, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.01, score=0.967, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.01, score=0.967, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.01, score=0.933, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.01, score=0.933, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.01, score=1.000, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.1, score=0.933, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.1, score=1.000, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.5, score=0.967, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.5, score=0.967, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.5, score=0.933, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.5, score=0.933, total=   0.1s
# [CV] max_depth=3, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=3, n_estimators=400, reg_lambda=0.5, score=1.000, total=   0.1s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.1, score=1.000, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=100, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.1, score=1.000, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=200, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.1, score=0.933, total=   0.1s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.1, score=1.000, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=5, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=300, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.01, score=0.967, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.01, score=0.967, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.01, score=0.933, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.01, score=0.933, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.01, score=1.000, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.1, score=0.933, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.1, score=0.933, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.1, score=1.000, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.5, score=0.967, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.5, score=0.967, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.5, score=0.933, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.5, score=0.933, total=   0.1s
# [CV] max_depth=5, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=5, n_estimators=400, reg_lambda=0.5, score=1.000, total=   0.1s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.1, score=1.000, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=100, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=100, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.1, score=1.000, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=200, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=200, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.01, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.01, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.01, score=0.933, total=   0.1s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.01, score=1.000, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.1, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.1, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.1, score=1.000, total=   0.1s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.5, score=0.967, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.5, score=0.933, total=   0.0s
# [CV] max_depth=7, n_estimators=300, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=300, reg_lambda=0.5, score=1.000, total=   0.0s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.01, score=0.967, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.01, score=0.967, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.01, score=0.933, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.01, score=0.933, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.01 ..................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.01, score=1.000, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.1, score=0.967, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.1, score=0.933, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.1, score=0.933, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.1 ...................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.1, score=1.000, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.5, score=0.967, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.5, score=0.967, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.5, score=0.933, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.5, score=0.933, total=   0.1s
# [CV] max_depth=7, n_estimators=400, reg_lambda=0.5 ...................
# [CV]  max_depth=7, n_estimators=400, reg_lambda=0.5, score=1.000, total=   0.1s
# {'max_depth': 3, 'n_estimators': 400, 'reg_lambda': 0.1}
#
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=400, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=0.1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)
# 0.9666666666666668
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed:    9.9s finished

# %%
#defining a set of values as a dictionary for hyperparameters
param_grid = {
    "n_estimators":[100,200,300,400],
    "max_depth":[1,3,5,7],
    "reg_lambda":[.01,.1,.5]    
}

#declaring RandomizedSearchCV model
model = model_selection.RandomizedSearchCV(
    estimator = clf,
    param_distributions = param_grid,
    scoring = 'accuracy',
    verbose = 10,
    n_jobs = 1,
    cv = 5,
    n_iter=10
)
#fitting values to the RandomizedSearchCV model
model.fit(X,y)
#printing the best possible values to enhance accuracy
print(model.best_params_)
print(model.best_estimator_)
#printing the best score
print(model.best_score_)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] reg_lambda=0.5, n_estimators=300, max_depth=7 ...................
# [CV]  reg_lambda=0.5, n_estimators=300, max_depth=7, score=0.967, total=   0.1s
# [CV] reg_lambda=0.5, n_estimators=300, max_depth=7 ...................
# [CV]  reg_lambda=0.5, n_estimators=300, max_depth=7, score=0.967, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=300, max_depth=7 ...................
# [CV]  reg_lambda=0.5, n_estimators=300, max_depth=7, score=0.933, total=   0.1s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [CV] reg_lambda=0.5, n_estimators=300, max_depth=7 ...................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.2s remaining:    0.0s
# [CV]  reg_lambda=0.5, n_estimators=300, max_depth=7, score=0.933, total=   0.1s
# [CV] reg_lambda=0.5, n_estimators=300, max_depth=7 ...................
# [CV]  reg_lambda=0.5, n_estimators=300, max_depth=7, score=1.000, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=100, max_depth=3 ..................
# [CV]  reg_lambda=0.01, n_estimators=100, max_depth=3, score=0.967, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=100, max_depth=3 ..................
# [CV]  reg_lambda=0.01, n_estimators=100, max_depth=3, score=0.967, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=100, max_depth=3 ..................
# [CV]  reg_lambda=0.01, n_estimators=100, max_depth=3, score=0.933, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=100, max_depth=3 ..................
# [CV]  reg_lambda=0.01, n_estimators=100, max_depth=3, score=0.933, total=   0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.2s remaining:    0.0s
# [CV] reg_lambda=0.01, n_estimators=100, max_depth=3 ..................
# [CV]  reg_lambda=0.01, n_estimators=100, max_depth=3, score=1.000, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=200, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=200, max_depth=5, score=0.967, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=200, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=200, max_depth=5, score=0.967, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=200, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=200, max_depth=5, score=0.933, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=200, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=200, max_depth=5, score=0.933, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=200, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=200, max_depth=5, score=1.000, total=   0.0s
# [CV] reg_lambda=0.1, n_estimators=100, max_depth=1 ...................
# [CV]  reg_lambda=0.1, n_estimators=100, max_depth=1, score=0.967, total=   0.0s
# [CV] reg_lambda=0.1, n_estimators=100, max_depth=1 ...................
# [CV]  reg_lambda=0.1, n_estimators=100, max_depth=1, score=0.967, total=   0.0s
# [CV] reg_lambda=0.1, n_estimators=100, max_depth=1 ...................
# [CV]  reg_lambda=0.1, n_estimators=100, max_depth=1, score=0.900, total=   0.0s
# [CV] reg_lambda=0.1, n_estimators=100, max_depth=1 ...................
# [CV]  reg_lambda=0.1, n_estimators=100, max_depth=1, score=0.933, total=   0.0s
# [CV] reg_lambda=0.1, n_estimators=100, max_depth=1 ...................
# [CV]  reg_lambda=0.1, n_estimators=100, max_depth=1, score=1.000, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=300, max_depth=7 ..................
# [CV]  reg_lambda=0.01, n_estimators=300, max_depth=7, score=0.967, total=   0.1s
# [CV] reg_lambda=0.01, n_estimators=300, max_depth=7 ..................
# [CV]  reg_lambda=0.01, n_estimators=300, max_depth=7, score=0.967, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=300, max_depth=7 ..................
# [CV]  reg_lambda=0.01, n_estimators=300, max_depth=7, score=0.933, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=300, max_depth=7 ..................
# [CV]  reg_lambda=0.01, n_estimators=300, max_depth=7, score=0.933, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=300, max_depth=7 ..................
# [CV]  reg_lambda=0.01, n_estimators=300, max_depth=7, score=1.000, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=100, max_depth=1 ..................
# [CV]  reg_lambda=0.01, n_estimators=100, max_depth=1, score=0.967, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=100, max_depth=1 ..................
# [CV]  reg_lambda=0.01, n_estimators=100, max_depth=1, score=0.967, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=100, max_depth=1 ..................
# [CV]  reg_lambda=0.01, n_estimators=100, max_depth=1, score=0.900, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=100, max_depth=1 ..................
# [CV]  reg_lambda=0.01, n_estimators=100, max_depth=1, score=0.933, total=   0.0s
# [CV] reg_lambda=0.01, n_estimators=100, max_depth=1 ..................
# [CV]  reg_lambda=0.01, n_estimators=100, max_depth=1, score=1.000, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=100, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=100, max_depth=5, score=0.967, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=100, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=100, max_depth=5, score=0.967, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=100, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=100, max_depth=5, score=0.933, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=100, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=100, max_depth=5, score=0.933, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=100, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=100, max_depth=5, score=1.000, total=   0.0s
# [CV] reg_lambda=0.1, n_estimators=400, max_depth=7 ...................
# [CV]  reg_lambda=0.1, n_estimators=400, max_depth=7, score=0.967, total=   0.1s
# [CV] reg_lambda=0.1, n_estimators=400, max_depth=7 ...................
# [CV]  reg_lambda=0.1, n_estimators=400, max_depth=7, score=0.967, total=   0.1s
# [CV] reg_lambda=0.1, n_estimators=400, max_depth=7 ...................
# [CV]  reg_lambda=0.1, n_estimators=400, max_depth=7, score=0.933, total=   0.1s
# [CV] reg_lambda=0.1, n_estimators=400, max_depth=7 ...................
# [CV]  reg_lambda=0.1, n_estimators=400, max_depth=7, score=0.933, total=   0.1s
# [CV] reg_lambda=0.1, n_estimators=400, max_depth=7 ...................
# [CV]  reg_lambda=0.1, n_estimators=400, max_depth=7, score=1.000, total=   0.1s
# [CV] reg_lambda=0.5, n_estimators=300, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=300, max_depth=5, score=0.967, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=300, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=300, max_depth=5, score=0.967, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=300, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=300, max_depth=5, score=0.933, total=   0.1s
# [CV] reg_lambda=0.5, n_estimators=300, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=300, max_depth=5, score=0.933, total=   0.0s
# [CV] reg_lambda=0.5, n_estimators=300, max_depth=5 ...................
# [CV]  reg_lambda=0.5, n_estimators=300, max_depth=5, score=1.000, total=   0.0s
# [CV] reg_lambda=0.1, n_estimators=300, max_depth=7 ...................
# [CV]  reg_lambda=0.1, n_estimators=300, max_depth=7, score=0.967, total=   0.1s
# [CV] reg_lambda=0.1, n_estimators=300, max_depth=7 ...................
# [CV]  reg_lambda=0.1, n_estimators=300, max_depth=7, score=0.967, total=   0.1s
# [CV] reg_lambda=0.1, n_estimators=300, max_depth=7 ...................
# [CV]  reg_lambda=0.1, n_estimators=300, max_depth=7, score=0.933, total=   0.0s
# [CV] reg_lambda=0.1, n_estimators=300, max_depth=7 ...................
# [CV]  reg_lambda=0.1, n_estimators=300, max_depth=7, score=0.933, total=   0.0s
# [CV] reg_lambda=0.1, n_estimators=300, max_depth=7 ...................
# [CV]  reg_lambda=0.1, n_estimators=300, max_depth=7, score=1.000, total=   0.1s
# {'reg_lambda': 0.5, 'n_estimators': 300, 'max_depth': 7}
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=7,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=0.5, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)
# 0.96
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    1.8s finished

# %%
#importing packages 
from functools import partial
from skopt import space
from skopt import gp_minimize

#defining a method that will perfrom a 5 split cross validation over
#dataset and and will produce the optimum value of the accuracy
def optimize(params, param_names, x,y):
    params = dict(zip(param_names,params))
    model = XGBClassifier(**params)
    kf = model_selection.StratifiedKFold(n_splits=5)
    accuracies = []
    for idx in kf.split(X=x,y=y):
        train_idx,test_idx = idx[0],idx[1]
        xtrain = x[train_idx]
        ytrain = y[train_idx]
        
        xtest = x[test_idx]
        ytest = y[test_idx]
        
        model.fit(xtrain,ytrain)
        preds =  model.predict(xtest)
        fold_acc = metrics.accuracy_score(ytest,preds)
        accuracies.append(fold_acc)
    return -1.0 * np.mean(accuracies)
 
#defining a set of values as space for hyperparameters
param_space = [
    space.Integer(3,15, name = "max_depth"),
    space.Integer(100,600, name = "n_estimators"),
    space.Real(0.01,1,prior='uniform', name="reg_lambda"),
    space.Real(0.01,1,prior='uniform', name="max_features")
]

#DEfining the parameter names
param_names = [
    "max_depth",
    "n_estimators",
    "reg_lambda",
    "max_features"
]

#defiing optimization_fuction as partial and calling optimize within it
optimization_fuction = partial(optimize, param_names = param_names,x = X, y = y) 

#Getting the optimum values for hyperparameters
result = gp_minimize(
    optimization_fuction,
    dimensions=param_space,
    n_calls = 15,
    n_random_starts= 10,
    verbose= 10
)

#Printing the best hyperparemeter set
print(dict(zip(param_names,result.x)))
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [21:13:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.3930
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 2 started. Evaluating function at random point.
# [21:13:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.3390
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 3 started. Evaluating function at random point.
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.3300
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 4 started. Evaluating function at random point.
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.3601
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 5 started. Evaluating function at random point.
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.3430
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 6 started. Evaluating function at random point.
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.2890
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 7 started. Evaluating function at random point.
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.4870
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 8 started. Evaluating function at random point.
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.2540
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 9 started. Evaluating function at random point.
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.5110
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 10 started. Evaluating function at random point.
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.4350
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 11 started. Searching for the next optimal point.
# [21:13:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.5820
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 12 started. Searching for the next optimal point.
# [21:13:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.6000
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 13 started. Searching for the next optimal point.
# [21:13:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [21:13:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.6120
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 14 started. Searching for the next optimal point.
# [21:13:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.5360
# Function value obtained: -0.9600
# Current minimum: -0.9600
# Iteration No: 15 started. Searching for the next optimal point.
# [21:13:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:39] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.7670
# Function value obtained: -0.9667
# Current minimum: -0.9667
# {'max_depth': 3, 'n_estimators': 548, 'reg_lambda': 0.011006327060053576, 'max_features': 0.934295108340534}

# %%
#importing packages 
from hyperopt import hp,fmin, tpe, Trials
from hyperopt.pyll.base import scope
from functools import partial
from skopt import space
from skopt import gp_minimize

#defining a method that will perfrom a 5 split cross validation over
#dataset and and will produce the optimum value of the accuracy
def optimize(params, x,y):
    clf = XGBClassifier(**params)
    kf = model_selection.StratifiedKFold(n_splits=5)
    accuracies = []
    for idx in kf.split(X=x,y=y):
        train_idx,test_idx = idx[0],idx[1]
        xtrain = x[train_idx]
        ytrain = y[train_idx]
        
        xtest = x[test_idx]
        ytest = y[test_idx]
        
        clf.fit(xtrain,ytrain)
        preds =  clf.predict(xtest)
        fold_acc = metrics.accuracy_score(ytest,preds)
        accuracies.append(fold_acc)
    return -1.0 * np.mean(accuracies)

#defining a set of values as hp for hyperparameters
param_space = {
    "max_depth" : scope.int(hp.quniform("max_depth",3,20, 1)) ,
    "min_child_weight" : scope.int(hp.quniform("min_child_weight",1,8, 1)),
    "n_estimators": scope.int(hp.quniform("n_estimators",100,1500,1)),
    'learning_rate': hp.uniform("learning_rate",0.01,1),
    'reg_lambda': hp.uniform("reg_lambda",0.01,1),
    'gamma': hp.uniform("gamma",0.01,1),
    'subsample': hp.uniform("subsample",0.01,1)
    }

#defiing optimization_fuction as partial and calling optimize within it
optimization_fuction = partial(optimize,x = X, y = y) 
trials = Trials()
#Getting the optimum values for hyperparameters
result = fmin(
    fn = optimization_fuction,
    space = param_space,
    algo = tpe.suggest,
    max_evals = 15,
    trials = trials
)
#Printing the best hyperparemeter set
print(result)
# Out:
# 100%|█████████████████████████████████████████████████████████████| 15/15 [00:12<00:00,  1.21trial/s, best loss: -0.96]
# {'gamma': 0.032643072533322604, 'learning_rate': 0.14981218674895688, 'max_depth': 11.0, 'min_child_weight': 2.0, 'n_estimators': 1279.0, 'reg_lambda': 0.26626102288641107, 'subsample': 0.6591228798054614}

# %%
#importing packages
import optuna
from functools import partial

#defining a method that will perfrom a 5 split cross validation over
#dataset and and will produce the optimum value of the accuracy
def optimize(trial, x,y):
    #parameter set is declare within function
    reg_lambda = trial.suggest_uniform('reg_lambda',0.01,1)
    n_estimators = trial.suggest_int('n_estimators',100,1500)
    max_depth = trial.suggest_int('max_depth',3,15)
    max_features = trial.suggest_uniform('max_features',0.01,1)
    
    clf = XGBClassifier(
    n_estimators= n_estimators,
    reg_lambda=reg_lambda,
    max_depth=max_depth,
    max_features= max_features)
    kf = model_selection.StratifiedKFold(n_splits=5)
    accuracies = []
    for idx in kf.split(X=x,y=y):
        train_idx,test_idx = idx[0],idx[1]
        xtrain = x[train_idx]
        ytrain = y[train_idx]
        
        xtest = x[test_idx]
        ytest = y[test_idx]
        
        clf.fit(xtrain,ytrain)
        preds =  clf.predict(xtest)
        fold_acc = metrics.accuracy_score(ytest,preds)
        accuracies.append(fold_acc)
    return -1.0 * np.mean(accuracies)

#defiing optimization_fuction as partial and calling optimize within it
optimization_fuction = partial(optimize,x = X, y = y) 

study = optuna.create_study(direction='minimize')

#Printing the best hyperparemeter set
study.optimize(optimization_fuction, n_trials=15)
# Out:
# [I 2021-06-08 21:13:50,858] A new study created in memory with name: no-name-c598a987-fd36-4717-9eda-6c2d713394bc
# [21:13:50] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:50] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:51,271] Trial 0 finished with value: -0.96 and parameters: {'reg_lambda': 0.4446835461848895, 'n_estimators': 432, 'max_depth': 9, 'max_features': 0.630718561778284}. Best is trial 0 with value: -0.96.
# [21:13:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:51,756] Trial 1 finished with value: -0.9666666666666668 and parameters: {'reg_lambda': 0.2647882878907975, 'n_estimators': 493, 'max_depth': 5, 'max_features': 0.77887766875908}. Best is trial 1 with value: -0.9666666666666668.
# [21:13:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:52,981] Trial 2 finished with value: -0.9666666666666668 and parameters: {'reg_lambda': 0.5603719970577606, 'n_estimators': 1408, 'max_depth': 5, 'max_features': 0.5326690845139341}. Best is trial 1 with value: -0.9666666666666668.
# [21:13:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:53,318] Trial 3 finished with value: -0.96 and parameters: {'reg_lambda': 0.30074413947720474, 'n_estimators': 316, 'max_depth': 9, 'max_features': 0.3803252820609118}. Best is trial 1 with value: -0.9666666666666668.
# [21:13:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:54,044] Trial 4 finished with value: -0.9666666666666668 and parameters: {'reg_lambda': 0.27005133985216945, 'n_estimators': 794, 'max_depth': 15, 'max_features': 0.222469827949626}. Best is trial 1 with value: -0.9666666666666668.
# [21:13:54] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:54] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:54] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:54] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:54] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:55,277] Trial 5 finished with value: -0.9666666666666668 and parameters: {'reg_lambda': 0.1553241906738249, 'n_estimators': 1293, 'max_depth': 4, 'max_features': 0.6502522458018145}. Best is trial 1 with value: -0.9666666666666668.
# [21:13:55] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:55] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:55] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:55] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:56] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:56,248] Trial 6 finished with value: -0.9666666666666668 and parameters: {'reg_lambda': 0.18471357138451316, 'n_estimators': 1066, 'max_depth': 15, 'max_features': 0.16165588531962985}. Best is trial 1 with value: -0.9666666666666668.
# [21:13:56] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:56] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:56] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:56] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:57,418] Trial 7 finished with value: -0.96 and parameters: {'reg_lambda': 0.1685701624418009, 'n_estimators': 1416, 'max_depth': 3, 'max_features': 0.2157001453261608}. Best is trial 1 with value: -0.9666666666666668.
# [21:13:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:58,304] Trial 8 finished with value: -0.9666666666666668 and parameters: {'reg_lambda': 0.22066090334750205, 'n_estimators': 945, 'max_depth': 5, 'max_features': 0.4455731771751504}. Best is trial 1 with value: -0.9666666666666668.
# [21:13:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:58,823] Trial 9 finished with value: -0.96 and parameters: {'reg_lambda': 0.5375061871903858, 'n_estimators': 608, 'max_depth': 4, 'max_features': 0.6639455545887376}. Best is trial 1 with value: -0.9666666666666668.
# [21:13:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:59,009] Trial 10 finished with value: -0.96 and parameters: {'reg_lambda': 0.8878202600854999, 'n_estimators': 154, 'max_depth': 7, 'max_features': 0.9782117544018288}. Best is trial 1 with value: -0.9666666666666668.
# [21:13:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:13:59,535] Trial 11 finished with value: -0.96 and parameters: {'reg_lambda': 0.6846240224729165, 'n_estimators': 542, 'max_depth': 7, 'max_features': 0.9462682562399234}. Best is trial 1 with value: -0.9666666666666668.
# [I 2021-06-08 21:13:59,727] Trial 12 finished with value: -0.96 and parameters: {'reg_lambda': 0.6763489154901902, 'n_estimators': 171, 'max_depth': 12, 'max_features': 0.7890105469993388}. Best is trial 1 with value: -0.9666666666666668.
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:13:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:14:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:14:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:14:00,428] Trial 13 finished with value: -0.96 and parameters: {'reg_lambda': 0.47061454142128784, 'n_estimators': 743, 'max_depth': 6, 'max_features': 0.8206948536450419}. Best is trial 1 with value: -0.9666666666666668.
# [21:14:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:14:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:14:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:14:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:14:01] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [21:14:01] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-06-08 21:14:01,408] Trial 14 finished with value: -0.9666666666666668 and parameters: {'reg_lambda': 0.6433263041858097, 'n_estimators': 1164, 'max_depth': 11, 'max_features': 0.48373695131101463}. Best is trial 1 with value: -0.9666666666666668.

# %%
21:13:50
